# %%
import pandas as pd
import numpy as np

# %%
v=pd.read_csv(r"C:\Users\user\Downloads\data set with questions\data set with questions\Weather Data.csv")

# %%
v
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 1     01-01-2012 01:00     7.4               2.8         20               24
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 3     01-01-2012 03:00     4.9              -2.6         27               15
# 4     01-01-2012 04:00   -13.4             -19.7         30                4
# ...                ...     ...               ...        ...              ...
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
# 8782    9/30/2012 8:00    -6.3             -13.5         99               15
# 8783    9/30/2012 9:00    24.5              14.7        100               11
#
# ...

# %%
v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
v.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
v["Wind Speed_km/h"].unique()
# Out:
# array([ 9, 24, 26, 15,  4,  0, 19, 17, 11, 22, 35, 13, 20,  6,  7, 30, 32,
#        41, 39, 28, 44, 33, 37, 52, 46,  2, 50, 48, 57, 63, 43, 83, 70, 54],
#       dtype=int64)

# %%
v.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
v.loc[v["Weather"]=="Clear"].count()
# Out:
# Date/Time           1326
# Temp_C              1326
# Dew Point Temp_C    1326
# Rel Hum_%           1326
# Wind Speed_km/h     1326
# Visibility_km       1326
# Press_kPa           1326
# Weather             1326
# dtype: int64

# %%
v.loc[v["Wind Speed_km/h"]==4].count()
# Out:
# Date/Time           474
# Temp_C              474
# Dew Point Temp_C    474
# Rel Hum_%           474
# Wind Speed_km/h     474
# Visibility_km       474
# Press_kPa           474
# Weather             474
# dtype: int64

# %%
v.isna().count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
v.rename(columns={"Weather":"Weather condition"},inplace=True)

# %%
v
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 1     01-01-2012 01:00     7.4               2.8         20               24
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 3     01-01-2012 03:00     4.9              -2.6         27               15
# 4     01-01-2012 04:00   -13.4             -19.7         30                4
# ...                ...     ...               ...        ...              ...
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
# 8782    9/30/2012 8:00    -6.3             -13.5         99               15
# 8783    9/30/2012 9:00    24.5              14.7        100               11
#
# ...

# %%
v["Visibility_km"].mean()
# Out:
# 27.664446721311478

# %%
v["Press_kPa"].std()
# Out:
# 0.8440047459486483

# %%
v["Rel Hum_%"].var()
# Out:
# 286.248550198502

# %%
v.loc[v["Weather condition"]=="Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 11    01-01-2012 11:00    -6.2              -9.6         37               35
# 70    03-01-2012 22:00    -4.0              -6.6         62               22
# 73    04-01-2012 01:00     2.3              -3.4         64               35
# 105   05-01-2012 09:00    -1.8              -4.2         73               15
# 112   05-01-2012 16:00     1.7              -0.3         75                6
# ...                ...     ...               ...        ...              ...
# 8573   9/22/2012 13:00    -6.0             -10.2         82               19
# 8650   9/25/2012 18:00    -4.6              -6.6         52                4
# 8671   9/26/2012 15:00    -5.9             -10.5         60               13
# 8713    9/28/2012 1:00    -5.2              -7.8         72               33
# 8734    9/28/2012 8:00     0.7              -1.2         79               30
#
# ...

# %%
v.loc[(v["Wind Speed_km/h"]==24)&(v["Visibility_km"]==25)].value_counts()
# Out:
# Date/Time         Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather condition
# 01-05-2012 15:00   15.4    13.3             59         24               25.0           100.85     Cloudy               1
# 6/16/2012 10:00    13.1    11.0             75         24               25.0           100.48     Rain Showers         1
# 5/29/2012 19:00   -11.9   -19.3             88         24               25.0           100.27     Mostly Cloudy        1
# 5/28/2012 18:00   -3.5    -7.9              83         24               25.0           100.19     Clear                1
# 5/21/2012 13:00    0.5    -7.2              78         24               25.0           100.24     Cloudy               1
#                                                                                                                       ..
# 1/20/2012 20:00   -13.8   -16.5             75         24               25.0           101.01     Clear                1
# ...

# %%
h=v.groupby("Weather condition")

# %%
h[["Press_kPa","Temp_C","Rel Hum_%","Wind Speed_km/h","Visibility_km","Temp_C",]].mean()
# Out:
#                                           Press_kPa     Temp_C  Rel Hum_%  \
# Weather condition
# Clear                                    101.084495   6.825716  67.127451
# Cloudy                                   101.056852   7.970544  67.349537
# Drizzle                                  101.099268   7.353659  69.048780
# Drizzle,Fog                              100.820750   8.067500  70.062500
# Drizzle,Ice Pellets,Fog                   99.440000   0.400000  52.000000
# Drizzle,Snow                             100.490000   1.050000  44.000000
# Drizzle,Snow,Fog                         100.971333   0.693333  69.800000
# Fog                                      101.149400   4.303333  66.466667
# Freezing Drizzle                         101.070000  -5.657143  68.857143
# Freezing Drizzle,Fog                     100.851667  -2.533333  64.000000
# Freezing Drizzle,Haze                    101.136667  -5.433333  63.333333
# ...

# %%
h[["Press_kPa","Temp_C","Rel Hum_%","Wind Speed_km/h","Visibility_km","Temp_C",]].min()
# Out:
#                                          Press_kPa  Temp_C  Rel Hum_%  \
# Weather condition
# Clear                                        97.75   -23.3         18
# Cloudy                                       97.52   -21.4         20
# Drizzle                                      98.29     1.1         37
# Drizzle,Fog                                  98.32     0.0         38
# Drizzle,Ice Pellets,Fog                      99.44     0.4         52
# Drizzle,Snow                                100.27     0.9         39
# Drizzle,Snow,Fog                             99.26     0.3         46
# Fog                                          97.97   -16.0         21
# Freezing Drizzle                             99.75    -9.0         43
# Freezing Drizzle,Fog                         98.81    -6.4         31
# Freezing Drizzle,Haze                       100.55    -5.8         32
# Freezing Drizzle,Snow                        99.74    -8.3         37
# ...

# %%
h[["Press_kPa","Temp_C","Rel Hum_%","Wind Speed_km/h","Visibility_km","Temp_C",]].max()
# Out:
#                                          Press_kPa  Temp_C  Rel Hum_%  \
# Weather condition
# Clear                                       103.63    32.8        100
# Cloudy                                      103.52    30.5        100
# Drizzle                                     103.58    18.8         97
# Drizzle,Fog                                 103.56    19.9         98
# Drizzle,Ice Pellets,Fog                      99.44     0.4         52
# Drizzle,Snow                                100.71     1.2         49
# Drizzle,Snow,Fog                            102.47     1.1         94
# Fog                                         103.22    20.8         99
# Freezing Drizzle                            101.78    -2.3         89
# Freezing Drizzle,Fog                        103.01    -0.3         80
# Freezing Drizzle,Haze                       101.83    -5.0         81
# Freezing Drizzle,Snow                       101.15    -3.3         90
# ...

# %%
v.loc[v["Weather condition"]=="Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 13    01-01-2012 13:00     9.5               7.8         40               13
# 53    03-01-2012 05:00    -3.6              -4.3         57                7
# 136   06-01-2012 16:00    14.8              13.5         80               19
# 197   09-01-2012 05:00     2.1               0.7         43               11
# 278   12-01-2012 14:00     1.2               0.6         70               13
# ...                ...     ...               ...        ...              ...
# 8475   9/18/2012 11:00     6.2               5.4         56                7
# 8511   9/19/2012 22:00    15.7              15.4         66                7
# 8518    9/19/2012 8:00    -2.9              -4.5         68                6
# 8537    9/20/2012 3:00    -0.5              -2.1         74                7
# 8771   9/30/2012 19:00    12.8              12.2         91               19
#
# ...

# %%
v.loc[(v["Weather condition"]=="clear")|(v["Visibility_km"]>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9     01-01-2012 09:00    20.0               3.8         35               17
# 17    01-01-2012 17:00    -6.8              -9.8         42               20
# 18    01-01-2012 18:00     2.3              -2.4         42                6
# 19    01-01-2012 19:00   -12.7             -17.2         43               17
# 23    01-01-2012 23:00    29.5              16.8         45                4
# ...                ...     ...               ...        ...              ...
# 8759    9/29/2012 9:00    -2.1             -10.9         86               24
# 8774   9/30/2012 21:00    23.0              14.7         92               13
# 8777    9/30/2012 3:00     9.3               5.8         95                9
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
#
# ...

# %%
v.loc[(v["Weather condition"]=="clear")&(v["Rel Hum_%"]>50)]
# Out:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather condition]
# Index: []

# %%
v.loc[v["Visibility_km"]>40]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 9     01-01-2012 09:00    20.0               3.8         35               17
# 17    01-01-2012 17:00    -6.8              -9.8         42               20
# 18    01-01-2012 18:00     2.3              -2.4         42                6
# 19    01-01-2012 19:00   -12.7             -17.2         43               17
# 23    01-01-2012 23:00    29.5              16.8         45                4
# ...                ...     ...               ...        ...              ...
# 8759    9/29/2012 9:00    -2.1             -10.9         86               24
# 8774   9/30/2012 21:00    23.0              14.7         92               13
# 8777    9/30/2012 3:00     9.3               5.8         95                9
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
#
# ...

# %%
v.loc[v["Rel Hum_%"]>50]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 29    02-01-2012 05:00   -15.5             -24.1         51               30
# 30    02-01-2012 06:00    18.2              16.1         51               11
# 31    02-01-2012 07:00    28.2              14.0         51               11
# 32    02-01-2012 08:00    15.4               9.8         52               26
# 33    02-01-2012 09:00    18.6               4.0         52                0
# ...                ...     ...               ...        ...              ...
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
# 8782    9/30/2012 8:00    -6.3             -13.5         99               15
# 8783    9/30/2012 9:00    24.5              14.7        100               11
#
# ...
